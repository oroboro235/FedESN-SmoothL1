# %%
import numpy as np
import os
import sys
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))
from config import path

# read npz
global_model = np.load(path.model_path+"global_har_sl1.npz")
global_Win = global_model['Win']
global_Wres = global_model['Wres']
global_Wout = global_model['Wout']

import matplotlib.pyplot as plt
from utils import plot_readout

plot_readout(global_Wout)
# Out:
# Sparsity of the readout: 42.40%

# %%
# Out:
# Sparsity of the readout: 0.23%

# %%
from data_loader import read_data
Xtr, ytr, Xte, yte = read_data("jpv")

# %%
print(Xtr.shape, ytr.shape, Xte.shape, yte.shape)
# Out:
# (270, 29, 12) (270,) (370, 29, 12) (370,)
